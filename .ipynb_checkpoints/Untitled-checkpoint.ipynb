# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('data.xlsx')

# %%
df
# Out:
#               Kota MAKANAN DAN MINUMAN JADI ROTI TAWAR ROTI MANIS DAN LAINNYA  \
# 0              NaN                     2021       2021                   2021
# 1         Simeulue                    23744         46                    348
# 2     Aceh Singkil                    26997       1077                   1093
# 3     Aceh Selatan                    38327        166                   1021
# 4    Aceh Tenggara                    28338        254                    761
# ..             ...                      ...        ...                    ...
# 510         Puncak                     8898          -                      -
# 511        Dogiyai                     4992         92                    486
# 512     Intan Jaya                     1468        153                      9
# 513         Deiyai                        -          -                      -
# 514  Kota Jayapura                    56616        795                   1165
#
#     KUE KERING BISKUIT SEMPRONG KUE BASAH MAKANAN GORENG BUBUR KACANG HIJAU  \
# 0                          2021      2021           2021               2021
# 1                           411      3903           1877                154
# 2                           566      1309           2966                558
# 3                           710      3243           2531                329
# 4                           514      1710           2488                363
# ..                          ...       ...            ...                ...
# 510                         755       115           6958                  -
# 511                         133       124            645                 22
# 512                           7         5            542                  -
# 513                           -         -              -                  -
# 514                         912      3382           1873                560
#
#     GADO GADO KETOPRAK NASI CAMPUR RAMES  ... BUBUR AYAM SIOMAY BATAGO  \
# 0                 2021              2021  ...       2021          2021
# 1                   54              1277  ...         15           164
# 2                  611               632  ...         54           270
# 3                  256              8938  ...         11           449
# 4                  443              1234  ...        110          1478
# ..                 ...               ...  ...        ...           ...
# 510                  -                 -  ...          -             -
# 511                  -              1592  ...          -             -
# 512                  -               282  ...          -             -
# 513                  -                 -  ...          -             -
# 514               2051             10783  ...        663           491
#
#     MAKANAN JADI LAINNYA AIR KEMASAN AIR GALON AIR TEH KEMASAN DAN BERSODA  \
# 0                   2021        2021      2021                        2021
# 1                     94         137      1587                          78
# 2                    201         254      1134                         118
# 3                     98         237       476                         329
# 4                    172         466       546                         312
# ..                   ...         ...       ...                         ...
# 510                    -          49       436                           -
# 511                   11          74         3                         611
# 512                    -         124         -                         188
# 513                    -           -         -                           -
# 514                 3543        2021      2563                        1114
#
#     SARI BUAH KEMASAN MINUMAN KESEHATAN MINUMAN JADI KOPI SUSU ES KRIM  \
# 0                                  2021                   2021    2021
# 1                                   313                   4114     396
# 2                                   145                   2253     876
# 3                                   425                   4892     862
# 4                                   613                   3634     822
# ..                                  ...                    ...     ...
# 510                                   -                      -       -
# 511                                 140                    679       -
# 512                                   -                      9       -
# 513                                   -                      -       -
# 514                                 678                   2301     648
#
#     ES LAINNYA
# 0         2021
# 1          286
# 2          356
# 3          335
# 4          414
# ..         ...
# 510          -
# 511          -
# 512         15
# 513          -
# 514        981
#
# [515 rows x 32 columns]

# %%
df.head(20)
# Out:
#                Kota MAKANAN DAN MINUMAN JADI ROTI TAWAR  \
# 0               NaN                     2021       2021
# 1          Simeulue                    23744         46
# 2      Aceh Singkil                    26997       1077
# 3      Aceh Selatan                    38327        166
# 4     Aceh Tenggara                    28338        254
# 5        Aceh Timur                    39395        330
# 6       Aceh Tengah                    48300        546
# 7        Aceh Barat                    67356        380
# 8        Aceh Besar                    51446        586
# 9             Pidie                    53479        435
# 10          Bireuen                    56157        185
# 11       Aceh Utara                    32540        273
# 12  Aceh Barat Daya                    34579        192
# 13        Gayo Lues                    55610        586
# 14     Aceh Tamiang                    32408        206
# 15       Nagan Raya                    58733        473
# 16        Aceh Jaya                    57598        314
# 17     Bener Meriah                    44421        266
# 18       Pidie Jaya                    54615        760
# 19  Kota Banda Aceh                   104906        879
df.dropna(inplace=True)
df.isna().sum()
# Out:
# Kota                                   0
# MAKANAN DAN MINUMAN JADI               0
# ROTI TAWAR                             0
# ROTI MANIS DAN LAINNYA                 0
# KUE KERING BISKUIT SEMPRONG            0
# KUE BASAH                              0
# MAKANAN GORENG                         0
# BUBUR KACANG HIJAU                     0
# GADO GADO KETOPRAK                     0
# NASI CAMPUR RAMES                      0
# NASI GORENG                            0
# NASI PUTIH                             0
# LONTONG KETUPAT SAYUR                  0
# SOTO GULE SOP RAWON                    0
# SAYUR MATENG                           0
# SATE TONGSENG                          0
# MIE BAKSO REBUS GORENG                 0
# MIE INSTAN                             0
# MAKANAN RINGAN ANAK ANAK               0
# IKAN MATANG                            0
# AYAM DAGING MATANG                     0
# DAGING OLAHAN SOSIS NUGGET             0
# BUBUR AYAM                             0
# SIOMAY BATAGO                          0
# MAKANAN JADI LAINNYA                   0
# AIR KEMASAN                            0
# AIR GALON                              0
# AIR TEH KEMASAN DAN BERSODA            0
# SARI BUAH KEMASAN MINUMAN KESEHATAN    0
# MINUMAN JADI KOPI SUSU                 0
# ES KRIM                                0
# ES LAINNYA                             0
# dtype: int64

# %%
df.head(5)
# Out:
#             Kota MAKANAN DAN MINUMAN JADI ROTI TAWAR ROTI MANIS DAN LAINNYA  \
# 1       Simeulue                    23744         46                    348
# 2   Aceh Singkil                    26997       1077                   1093
# 3   Aceh Selatan                    38327        166                   1021
# 4  Aceh Tenggara                    28338        254                    761
# 5     Aceh Timur                    39395        330                    790
#
#   KUE KERING BISKUIT SEMPRONG KUE BASAH MAKANAN GORENG BUBUR KACANG HIJAU  \
# 1                         411      3903           1877                154
# 2                         566      1309           2966                558
# 3                         710      3243           2531                329
# 4                         514      1710           2488                363
# 5                         549      2644           2625                929
#
#   GADO GADO KETOPRAK NASI CAMPUR RAMES  ... BUBUR AYAM SIOMAY BATAGO  \
# 1                 54              1277  ...         15           164
# 2                611               632  ...         54           270
# 3                256              8938  ...         11           449
# 4                443              1234  ...        110          1478
# 5                227              4189  ...        171          1062
#
#   MAKANAN JADI LAINNYA AIR KEMASAN AIR GALON AIR TEH KEMASAN DAN BERSODA  \
# 1                   94         137      1587                          78
# 2                  201         254      1134                         118
# 3                   98         237       476                         329
# 4                  172         466       546                         312
# 5                  269         645       748                         506
#
#   SARI BUAH KEMASAN MINUMAN KESEHATAN MINUMAN JADI KOPI SUSU ES KRIM  \
# 1                                 313                   4114     396
# 2                                 145                   2253     876
# 3                                 425                   4892     862
# 4                                 613                   3634     822
# 5                                 366                   7494    1166
#
#   ES LAINNYA
# 1        286
# 2        356
# 3        335
# 4        414
# 5        258
#
# [5 rows x 32 columns]

# %%
x = df.iloc[[1],1]

# %%
x
# Out:
# 2    26997
# Name: MAKANAN DAN MINUMAN JADI, dtype: object

# %%
#menggunakan minmax scaler
minmax = preprocessing.MinMaxScaler().fit_transform(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [76], in <cell line: 2>()
#       1 #menggunakan minmax scaler
# ----> 2 minmax = preprocessing.MinMaxScaler().fit_transform(df)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:867, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     863 # non-optimized default implementation; override when a better
#     864 # method is possible for a given clustering algorithm
#     865 if y is None:
#     866     # fit method of arity 1 (unsupervised transformation)
# --> 867     return self.fit(X, **fit_params).transform(X)
#     868 else:
#     869     # fit method of arity 2 (supervised transformation)
#     870     return self.fit(X, y, **fit_params).transform(X)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_data.py:420, in MinMaxScaler.fit(self, X, y)
#     418 # Reset internal state before fitting
#     419 self._reset()
# --> 420 return self.partial_fit(X, y)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_data.py:457, in MinMaxScaler.partial_fit(self, X, y)
#     451     raise TypeError(
#     452         "MinMaxScaler does not support sparse input. "
#     453         "Consider using MaxAbsScaler instead."
#     454     )
#     456 first_pass = not hasattr(self, "n_samples_seen_")
# --> 457 X = self._validate_data(
#     458     X,
#     459     reset=first_pass,
#     460     dtype=FLOAT_DTYPES,
#     461     force_all_finite="allow-nan",
#     462 )
#     464 data_min = np.nanmin(X, axis=0)
#     465 data_max = np.nanmax(X, axis=0)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:577, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     575     raise ValueError("Validation should be done on X, y or both.")
#     576 elif not no_val_X and no_val_y:
# --> 577     X = check_array(X, input_name="X", **check_params)
#     578     out = X
#     579 elif no_val_X and not no_val_y:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:856, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     854         array = array.astype(dtype, casting="unsafe", copy=False)
#     855     else:
# --> 856         array = np.asarray(array, order=order, dtype=dtype)
#     857 except ComplexWarning as complex_warning:
#     858     raise ValueError(
#     859         "Complex data not supported\n{}\n".format(array)
#     860     ) from complex_warning
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:2064, in NDFrame.__array__(self, dtype)
#    2063 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2064     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'Simeulue'

# %%
df3 = minmax

# %%
df3
# Out:
# MinMaxScaler(feature_range=    MAKANAN DAN MINUMAN JADI ROTI TAWAR ROTI MANIS DAN LAINNYA  \
# 1                      23744         46                    348
# 2                      26997       1077                   1093
# 3                      38327        166                   1021
# 4                      28338        254                    761
# 5                      39395        330                    790
# ..                       ...        ...                    ...
# 510                     8898          -                      -
# 511                     4992         92                    486
# 512                     1468        153                      9
# 513                        -          -                      -
# 514                    56616        795                   1165
#
#     KUE KERING BISKUIT SEMPRONG KUE BASAH MAKANAN GORENG BUBUR KACANG HIJAU  \
# 1                           411      3903           1877                154
# 2                           566      1309           2966                558
# 3                           710      3243           2531                329
# 4                           514      1710           2488                363
# 5                           549      2644           2625                929
# ..                          ...       ...            .....
# ..            ...                  ...         ...       ...
# 510             -                    -          49       436
# 511             -                   11          74         3
# 512             -                    -         124         -
# 513             -                    -           -         -
# 514           491                 3543        2021      2563
#
#     AIR TEH KEMASAN DAN BERSODA SARI BUAH KEMASAN MINUMAN KESEHATAN  \
# 1                            78                                 313
# 2                           118                                 145
# 3                           329                                 425
# 4                           312                                 613
# 5                           506                                 366
# ..                          ...                                 ...
# 510                           -                                   -
# 511                         611                                 140
# 512                         188                                   -
# 513                           -                                   -
# 514                        1114                                 678
#
#     MINUMAN JADI KOPI SUSU ES KRIM ES LAINNYA
# 1                     4114     396        286
# 2                     2253     876        356
# 3                     4892     862        335
# 4                     3634     822        414
# 5                     7494    1166        258
# ..                     ...     ...        ...
# 510                      -       -          -
# 511                    679       -          -
# 512                      9       -         15
# 513                      -       -          -
# 514                   2301     648        981
#
# [514 rows x 31 columns])

# %%
KMeans(n_clusters=2).fit(df).score(df3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [67], in <cell line: 1>()
# ----> 1 KMeans(n_clusters=2).fit(df).score(df3)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1365, in KMeans.fit(self, X, y, sample_weight)
#    1339 def fit(self, X, y=None, sample_weight=None):
#    1340     """Compute k-means clustering.
#    1341
#    1342     Parameters
#    (...)
#    1363         Fitted estimator.
#    1364     """
# -> 1365     X = self._validate_data(
#    1366         X,
#    1367         accept_sparse="csr",
#    1368         dtype=[np.float64, np.float32],
#    1369         order="C",
#    1370         copy=self.copy_x,
#    1371         accept_large_sparse=False,
#    1372     )
#    1374     self._check_params(X)
#    1375     random_state = check_random_state(self.random_state)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:577, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     575     raise ValueError("Validation should be done on X, y or both.")
#     576 elif not no_val_X and no_val_y:
# --> 577     X = check_array(X, input_name="X", **check_params)
#     578     out = X
#     579 elif no_val_X and not no_val_y:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:856, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     854         array = array.astype(dtype, casting="unsafe", copy=False)
#     855     else:
# --> 856         array = np.asarray(array, order=order, dtype=dtype)
#     857 except ComplexWarning as complex_warning:
#     858     raise ValueError(
#     859         "Complex data not supported\n{}\n".format(array)
#     860     ) from complex_warning
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:2064, in NDFrame.__array__(self, dtype)
#    2063 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2064     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'Simeulue'
